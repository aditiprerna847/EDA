# %%
import pandas as pd
import numpy as np
#!pip install selenium
#!pip install BeautifulSoup4
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %%
# import requests
# webpage=requests.get('https://github.com/CSSEGISandData/COVID-19/tree/master/csse_covid_19_data/csse_covid_19_daily_reports').text

# soup=BeautifulSoup(webpage,'lxml')
# date=[]
# for i in soup.find_all('a',class_="js-navigation-open Link--primary"):
#   #print(i.text[0:10].strip())
#   date.append(i.text[0:10].strip())
    
# def scrapper(date):
#     url="https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/"+date
#     ii=".csv"
#     furl=url+ii+"?raw=true"
#     fetch = pd.read_csv(furl)
#     return fetch

# for i in date[1:]:
    
#     df=scrapper(i)
#     df.to_csv("covidall.csv", mode='a', index=False, header=df.columns)
#     print(f"{i} --> Data Fetched")

# %%
cf=pd.read_csv("covidall.csv")

# %%
cf.shape
# Out:
# (2965570, 14)

# %%
cf.sample(6)
# Out:
#             FIPS      Admin2    Province_State Country_Region  \
# 1199455      NaN         NaN  Himachal Pradesh          India
# 2431636  42033.0  Clearfield      Pennsylvania             US
# 542283   48257.0     Kaufman             Texas             US
# 1018189  20043.0    Doniphan            Kansas             US
# 1893037      NaN         NaN               NaN   Burkina Faso
# 2700301  47109.0     McNairy         Tennessee             US
#
#                  Last_Update                 Lat         Long_ Confirmed  \
# 1199455  2021-05-24 04:20:53           31.927213     77.233081    179034
# 2431636  2020-10-27 04:24:45         41.00110782  -78.47592663       445
# 542283   2022-03-09 04:20:59  32.599141700000004  -96.28734728     34960
# 1018189  2021-04-29 04:20:55         39.79067154  -95.14056866       967
# 1893037  2020-08-21 04:27:41             12.2383       -1.5616      1297
# 2700301  2021-11-29 04:22:30         35.17468549   -88.5647812      4795
#
# ...

# %%
cf.isnull().sum()
# Out:
# FIPS                    530758
# Admin2                  523426
# Province_State          133013
# Country_Region              28
# Last_Update                433
# Lat                      64079
# Long_                    67612
# Confirmed                 3918
# Deaths                    9243
# Recovered              1520772
# Active                 1520773
# Combined_Key              9242
# Incident_Rate           286839
# Case_Fatality_Ratio     259045
# dtype: int64

# %%
df=pd.DataFrame(cf)
df
# Out:
#         FIPS Admin2 Province_State        Country_Region          Last_Update  \
# 0        NaN    NaN            NaN           Afghanistan  2021-01-02 05:22:33
# 1        NaN    NaN            NaN               Albania  2021-01-02 05:22:33
# 2        NaN    NaN            NaN               Algeria  2021-01-02 05:22:33
# 3        NaN    NaN            NaN               Andorra  2021-01-02 05:22:33
# 4        NaN    NaN            NaN                Angola  2021-01-02 05:22:33
# ...      ...    ...            ...                   ...                  ...
# 2965565  NaN    NaN            NaN              Zimbabwe  2022-01-01 04:22:14
# 2965566  NaN    NaN            NaN  Winter Olympics 2022  2022-01-01 04:22:14
# 2965567  NaN    NaN            NaN            Antarctica  2022-01-01 04:22:14
# 2965568  NaN    NaN         Jersey        United Kingdom  2022-01-01 04:22:14
# 2965569  NaN    NaN       Guernsey        United Kingdom  2022-01-01 04:22:14
#
# ...

# %%
#percent=100*(len(df.loc[:,df.isna().any(axis=1)]))
#print(round(percent,2))
#percent
nan_values = df[df.isna().any(axis=1)]
nan_values
# Out:
#         FIPS Admin2 Province_State        Country_Region          Last_Update  \
# 0        NaN    NaN            NaN           Afghanistan  2021-01-02 05:22:33
# 1        NaN    NaN            NaN               Albania  2021-01-02 05:22:33
# 2        NaN    NaN            NaN               Algeria  2021-01-02 05:22:33
# 3        NaN    NaN            NaN               Andorra  2021-01-02 05:22:33
# 4        NaN    NaN            NaN                Angola  2021-01-02 05:22:33
# ...      ...    ...            ...                   ...                  ...
# 2965565  NaN    NaN            NaN              Zimbabwe  2022-01-01 04:22:14
# 2965566  NaN    NaN            NaN  Winter Olympics 2022  2022-01-01 04:22:14
# 2965567  NaN    NaN            NaN            Antarctica  2022-01-01 04:22:14
# 2965568  NaN    NaN         Jersey        United Kingdom  2022-01-01 04:22:14
# 2965569  NaN    NaN       Guernsey        United Kingdom  2022-01-01 04:22:14
#
# ...

# %%
x=nan_values.count()
x
# Out:
# FIPS                   1544809
# Admin2                 1552141
# Province_State         1942554
# Country_Region         2075539
# Last_Update            2075134
# Lat                    2011488
# Long_                  2007955
# Confirmed              2071649
# Deaths                 2066324
# Recovered               554795
# Active                  554794
# Combined_Key           2066325
# Incident_Rate          1788728
# Case_Fatality_Ratio    1816522
# dtype: int64

# %%
label = list(df.columns)
print(label)
# Out:
# ['FIPS', 'Admin2', 'Province_State', 'Country_Region', 'Last_Update', 'Lat', 'Long_', 'Confirmed', 'Deaths', 'Recovered', 'Active', 'Combined_Key', 'Incident_Rate', 'Case_Fatality_Ratio']

# %%
graph=plt.pie(x,labels=label,autopct='%1.1f%%')
# it gives the percentage of NaN values present in each attribute

# %%
y=x.max()
y
# Out:
# 2075539

# %%
print('hi')
# Out:
# hi

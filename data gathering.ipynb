# %%
import pandas as pd
import numpy as np
#!pip install selenium
#!pip install BeautifulSoup4
from bs4 import BeautifulSoup  # to scrap web

# %%
import ssl  #to certify links
ssl._create_default_https_context = ssl._create_unverified_context

# %%
# import requests
# webpage=requests.get('https://github.com/CSSEGISandData/COVID-19/tree/master/csse_covid_19_data/csse_covid_19_daily_reports').text

# soup=BeautifulSoup(webpage,'lxml') #to convert it in readable form [soupify process]
# date=[]
# for i in soup.find_all('a',class_="js-navigation-open Link--primary"):
#   #print(i.text[0:10].strip())
#   date.append(i.text[0:10].strip())
    
# def scrapper(date):
#     url="https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/"+date
#     ii=".csv"
#     furl=url+ii+"?raw=true"  #raw(arranged) ko thik karna  (concatenate)
#     fetch = pd.read_csv(furl)
#     return fetch

# for i in date[1:len(date)]:
#     df=scrapper(i)
#     df.to_csv("covidall.csv", mode='a', index=False, header=df.columns)  # to convert df to csv file
#     #header fun is used to get the same col as in df 
#     print(f"{i} --> Data Fetched")
# Out:
# 01-01-2021 --> Data Fetched
# 01-01-2022 --> Data Fetched
# 01-02-2021 --> Data Fetched
# 01-02-2022 --> Data Fetched
# 01-03-2021 --> Data Fetched
# 01-03-2022 --> Data Fetched
# 01-04-2021 --> Data Fetched
# 01-04-2022 --> Data Fetched
# 01-05-2021 --> Data Fetched
# 01-05-2022 --> Data Fetched
# 01-06-2021 --> Data Fetched
# 01-06-2022 --> Data Fetched
# 01-07-2021 --> Data Fetched
# 01-07-2022 --> Data Fetched
# 01-08-2021 --> Data Fetched
# 01-08-2022 --> Data Fetched
# 01-09-2021 --> Data Fetched
# 01-09-2022 --> Data Fetched
# 01-10-2021 --> Data Fetched
# 01-10-2022 --> Data Fetched
# 01-11-2021 --> Data Fetched
# 01-11-2022 --> Data Fetched
# 01-12-2021 --> Data Fetched
# 01-12-2022 --> Data Fetched
# 01-13-2021 --> Data Fetched
# 01-13-2022 --> Data Fetched
# 01-14-2021 --> Data Fetched
# 01-14-2022 --> Data Fetched
# 01-15-2021 --> Data Fetched
# 01-15-2022 --> Data Fetched
# 01-16-2021 --> Data Fetched
# 01-16-2022 --> Data Fetched
# 01-17-2021 --> Data Fetched
# ...

# %%
cf=pd.read_csv("covidall.csv")

# %%
cf.shape
# Out:
# (2965570, 14)

# %%
cf.sample(10)
# Out:
#             FIPS     Admin2                    Province_State Country_Region  \
# 2874056   1021.0    Chilton                           Alabama             US
# 2725562      NaN        NaN                  Chechen Republic         Russia
# 13001     8099.0    Prowers                          Colorado             US
# 1282804      NaN        NaN                  Chechen Republic         Russia
# 31115    72029.0  Canovanas                       Puerto Rico             US
# 612522   45001.0  Abbeville                    South Carolina             US
# 1221142      NaN        NaN  Bonaire, Sint Eustatius and Saba    Netherlands
# 1401635  72105.0  Naranjito                       Puerto Rico             US
# 2204415  51115.0    Mathews                          Virginia             US
# 2191240  36019.0    Clinton                          New York             US
#
#                  Last_Update                Lat         Long_ Confirmed  \
# ...

# %%
cf.isnull().sum()
# Out:
# FIPS                    530758
# Admin2                  523426
# Province_State          133013
# Country_Region              28
# Last_Update                433
# Lat                      64079
# Long_                    67612
# Confirmed                 3918
# Deaths                    9243
# Recovered              1520772
# Active                 1520773
# Combined_Key              9242
# Incident_Rate           286839
# Case_Fatality_Ratio     259045
# dtype: int64
